# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OrdinalEncoder, OneHotEncoder
from sklearn.decomposition import PCA

from sklearn.feature_selection import VarianceThreshold, SelectFromModel, RFECV, SequentialFeatureSelector

from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.metrics import accuracy_score

from sklearn.datasets import make_classification, load_wine, load_breast_cancer, load_diabetes, load_digits

# %%
plt.style.use('seaborn-darkgrid')

# %%
def plot_scatter(x, y, auto_scaled=True, title=None, clusters=None):
    plt.figure(figsize=(4, 4))
    plt.scatter(x, y, c=clusters, cmap='bwr')
    
    if not auto_scaled:
        plt.axis('square')
    
    plt.grid(True)
    plt.title(title)
    
    plt.show()
    
def return_X_y(data, target_column):
    return data.drop(target_column, axis=1), data[target_column]

# %%
wine_sklearn = load_wine(as_frame=True)
wine_data, wine_labels = wine_sklearn['data'], wine_sklearn['target']

# %% [markdown]
# # Homework

# %% [markdown]
# ## Exercise  1 - Scaling (2 points)

# %% [markdown]
# Perform standardization for wine dataset (`wine_data`) using only basic python, numpy and pandas (without using `StandardScaler` and sklearn at all). Implementation of function (or class) that can get dataset as input and return standardized dataset as output is preferrable, but not necessary.
#
# Compare you results (output) with `StandardScaler`.
#
# **NOTE:**
#
# - 1 point for functional version, 2 points for implementing scaling as sklearn pipeline compartible class.
# - Maximum for the exercise is 2 points.

# %% [markdown]
# ### Simple version (1 point)

# %%
# 1 point
def scale(X):
    return (X-np.mean(X))/(np.std(X))
    # your code here

# %%
assert np.allclose(np.array(scale(wine_data)), StandardScaler().fit_transform(wine_data))

# %% [markdown]
# ### Pipeline Version (2 points)

# %%
# 2 points
from sklearn.base import BaseEstimator, TransformerMixin
class CustomScaler(BaseEstimator, TransformerMixin):
    def __init__(self, columns=None, copy=True, with_mean=True, with_std=True):
        self.columns = columns
        self.copy = copy
        self.with_mean = with_mean
        self.with_std = with_std

    def fit(self, X, y=None):
        self.mean_ = np.mean(X) 
        self.std_ = np.std(X)
        return self
         
    def transform(self, X, y=None, copy=None):
        return (X-self.mean_)/self.std_

# %%
assert np.allclose(CustomScaler().fit_transform(wine_data), StandardScaler().fit_transform(wine_data))

# %% [markdown]
# ## Exercise  2 - Visualization (3 points)

# %% [markdown]
# As noted earlier, standardization/normalization of data can be crucial for some distance-based ML methods.
#
# Let’s generate some toy example of unnormalized data and visualize the importance of this process once more:

# %%
feature_0 = np.random.randn(1000) * 10   
feature_1 = np.concatenate([np.random.randn(500), np.random.randn(500) + 5])
data = np.column_stack([feature_0, feature_1])
data
# Out:
# array([[ -7.27949916,  -0.25314855],
#        [ -7.45188298,  -1.27663083],
#        [-19.19930829,  -0.02856374],
#        ...,
#        [  1.64380151,   3.64225195],
#        [ -2.57511419,   4.03938395],
#        [ -0.61918256,   5.10930106]])

# %%
plot_scatter(data[:, 0], data[:, 1], auto_scaled=True, title='Data (different axes units!)')

# %% [markdown]
# **NOTE:** on the plot above axes are scaled differently and we can clearly see two potential *classes/clusters*. In fact `matplotlib` performed `autoscaling` (which is basically can be considered as `MinMaxScaling` of original data) just for better visualization purposes.
#
# Let's turn this feature off and visualize the original data on the plot with equally scaled axes:

# %%
plot_scatter(data[:, 0], data[:, 1], auto_scaled=False , title='Data (equal axes units!)')

# %% [markdown]
# This picture is clearly less interpretable, but much closer to "how distance-based algorithm see the original data": separability of data is hardly noticable only because the variation (std) of x-feature is much bigger in absolute numbers.

# %% [markdown]
# Perform `StandardScaling` and `MinMaxScaling` of original data; visualize results for each case (**use `plot_scatter` with `auto_scaled=False`**):

# %% [markdown]
# ### MinMaxScaling (0.5 point)

# %%
## your code
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(data)
plot_scatter(normalized_data[:, 0], normalized_data[:, 1], auto_scaled=False , title='Data (MinMaxScaling)')

# %% [markdown]
# ### StandardScaler (0.5 point)

# %%
## your code
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)
plot_scatter(data_scaled[:, 0], data_scaled[:, 1], auto_scaled=False , title='Data (MinMaxScaling)')

# %% [markdown]
# ### (Bonus) K-means (2 points)

# %% [markdown]
# Illustrate the impact of scaling on basic distance-based clustering algorithm [K-means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) using `data` generated above.
#
# **NOTE:** basically, you don't need understanding K-means algorithm here, you just need to:
#
# 1) run algorithm (with k=2, k - number of clusters/classes) on unscaled data
# 2) run algorithm (with k=2) on scaled data
# 3) plot results: highlight different clusters using different colors.
#
# You can use this [question](https://stats.stackexchange.com/questions/89809/is-it-important-to-scale-data-before-clustering/89813) as a hint, but I recommend you to plot results using `plot_scatter` with `equal_scaled=True`: it might help you to intuitively understand the reasons of such scaling impact.

# %%
## your code
from sklearn.cluster import KMeans

Kmean = KMeans(n_clusters=2)
Kmean.fit(data)
Kmean.cluster_centers_
plt.scatter(data[ : , 0], data[ : , 1], s =50, c='b')
plt.scatter(Kmean.cluster_centers_[0,0],Kmean.cluster_centers_[0,1], s=200, c='g', marker='s')
plt.scatter(Kmean.cluster_centers_[1,0],Kmean.cluster_centers_[1,1], s=200, c='r', marker='s')
plt.show()

# %%
Kmean.fit(data_scaled)
Kmean.cluster_centers_
plt.scatter(data_scaled[ : , 0], data_scaled[ : , 1], s =50, c='b')
plt.scatter(Kmean.cluster_centers_[0,0],Kmean.cluster_centers_[0,1], s=200, c='g', marker='s')
plt.scatter(Kmean.cluster_centers_[1,0],Kmean.cluster_centers_[1,1], s=200, c='r', marker='s')
plt.show()

# %% [markdown]
# ## Exercise  3 - Preprocessing Pipeline (2 points)

# %%
wine_train, wine_val, wine_labels_train, wine_labels_val = train_test_split(wine_data, wine_labels, 
                                                                            test_size=0.3, random_state=42)

# %% [markdown]
# Train model (for example, `LogisticRegression(solver='liblinear', penalty='l1')` on raw `wine_train` data; then train same model after data scaling; then add feature selection (and train model again on scaled data). For each experiment all required preprocessing steps (if any) should be wrapped into sklearn pipeline.
#
# Measure `accuracy` of all 3 approaches on `wine_val` dataset. Describe and explain results.

# %%
## your code
def make_model(scaler, selector):
    
    if (scaler == False) and (selector == False):
        return Pipeline([('reg', LogisticRegression(solver='liblinear', penalty='l1'))])
    
    elif (scaler == True) and (selector == False):
        return Pipeline([
            ('scaler', StandardScaler()),
            ('reg', LogisticRegression(solver='liblinear', penalty='l1'))
        ])

    elif (scaler == True) and (selector == True):
        return Pipeline([
            ('scaler', StandardScaler()),
            ('selector', SelectFromModel(RandomForestClassifier(random_state=42))),
            ('reg', LogisticRegression(solver='liblinear', penalty='l1')) 
        ])
    
model1 = make_model(scaler=False, selector=False)
model1.fit(wine_train,wine_labels_train)
test_acc_1 = accuracy_score(y_pred=model1.predict(wine_val), y_true=wine_labels_val)

model2 = make_model(scaler=True, selector=False)
model2.fit(wine_train,wine_labels_train)
test_acc_2 = accuracy_score(y_pred=model2.predict(wine_val), y_true=wine_labels_val)

model3 = make_model(scaler=True, selector=True)
model3.fit(wine_train,wine_labels_train)
test_acc_3 = accuracy_score(y_pred=model3.predict(wine_val), y_true=wine_labels_val)

test_acc = [test_acc_1, test_acc_2, test_acc_3]
test_acc
# Out:
# [0.9814814814814815, 0.9814814814814815, 1.0]

# %% [markdown]
# Модель достаточно хорошо предсказывает данные и без скалирования и выбора признаков,  я думаю это связано с тем что в качестве модели используется линейная регресия с L1. Регуляризация уменьшает вклад признаков с большими значениями, которые скорее всего не важны. (Иначе не было б такой высокой точности без скалирования)
# При выборе признаков по методу RandomForest модель предсказывает абсолютно все результаты.

# %% [markdown]
# ## Exercise 4 - manual PCA (5 points)
# The task is to solve PCA as an optimization problem, without explicitly doing eigen value decomposition.
# In the most general setting PCA is minimization of reconstruction error of a projection of given rank $q$
#
# $$\min_{\mu, \lambda_1,\ldots, \lambda_n, \mathbf{V}_q} \sum_{i=1}^n ||x_i - \mu - \mathbf{V}_q \lambda_i||^2$$
#
# With a number of steps that can be found here https://stats.stackexchange.com/a/10260 this task transforms to
#  $$\max_{u_i} \sum_{i=1}^q u_i^T \mathbf{S} u_i$$
#  where $\mathbf{S}$ is the sample covariance matrix (after standartization) and $u_1, \ldots, u_q$ are the $q$ are orthonormal columns in $\mathbf{V}_q$.
#  Let us solve this optimization problem with `scipy.optimize` library.
#
#  Additional 2 point are given for visualization of the results.

# %% [markdown]
# ### PCA (3 points)

# %%
wine_data, wine_labels = wine_sklearn['data'], wine_sklearn['target']

# %% [markdown]
# Find a covariance matrix of standartized data and assing it to S.

# %%
## your code
S = np.array(StandardScaler().fit_transform(wine_data))
S = np.cov(S.T, ddof=1)

# %% [markdown]
# If your code is correct, the following assert should be Ok.

# %%
assert np.allclose(np.linalg.norm(S), 5.787241159764733)

# %%
from scipy.optimize import minimize

def objective(x):
    
    # your code: write objective of the problem (don't forget that scipy does min while we need max)
    return -(x.T@S@x)

def norm_constraint(x):
    # your code: constaraint norm of x to be 1, function should return 0 if constraint holds
    return np.linalg.norm(x)-1 

con1 = {'type': 'eq', 'fun': norm_constraint}

x0 = np.ones(13)# your code: initial vector to start optimization

sol = minimize(objective, 
               x0, 
               constraints = [con1]
              )
x0 = sol.x

# %% [markdown]
# Hurray! We have first vector! Let's do another one.

# %%
def orthogonality_constraint(x):
    # your code: x should be orthogonal to x0, function should return 0 if constraint holds
    return x.T@x0

con2 = {'type': 'eq', 'fun': orthogonality_constraint}

x1 = np.ones(13)# your code: initial vector to start optimization


sol = minimize(objective, 
               x1, 
               constraints = [con1, con2]#your code
              )

x1 = sol.x

# %% [markdown]
# If your solution is correct, the following asserts should be Ok.

# %%
assert np.allclose(x0@S@x0, 4.732436977583595)
assert np.allclose(x1@S@x1, 2.5110809296451233)

# %% [markdown]
# ### Visualization (2 points)

# %% [markdown]
# Visualize the points after applying custom dimension reduction with 2 components.

# %%
wine_data_scaled = np.array(CustomScaler().fit_transform(wine_data))
wine_data_x0 = wine_data_scaled@x0
wine_data_x1 = wine_data_scaled@x1
wine_data_PCA = np.concatenate((wine_data_x0[:,np.newaxis],wine_data_x1[:,np.newaxis]), axis=1)

# %%
fig,(ax1) = plt.subplots(ncols=1, figsize=(18, 10))

for l, c, m in zip(range(0, 3), ('blue', 'red', 'green'), ('^', 's', 'o')):
    ax1.scatter(wine_data_PCA[wine_labels == l, 0], wine_data_PCA[wine_labels == l, 1], 
                color=c, label=f'class {l}', alpha=0.5, marker=m)

ax1.set_title('Dataset after PCA')
ax1.set_xlabel('1st principal component')
ax1.set_ylabel('2nd principal component')
ax1.legend(loc='upper right')

# %% [markdown]
# График получился почему то вверх ногами. Как я успел найти это из-за того что X1 направлен в противоположную сторону. Почему так надо подумать, а времени уже нет)

# %% [markdown]
# ## Exercise 5 - Boruta (3 points)
#
# Let us classify handwritten digits 0, 1 and 2.
# To make task not so easy the images are binarized (no shadows of gray present) as it happens with xerocopied documents.
#
# Let us also find out to which parts of an image there's no need to look in order to clasify three digits of interest.

# %%
X, y = load_digits(n_class=3, return_X_y=True, as_frame=True)
X = (X>10).astype(int)

# %%
f, ax = plt.subplots(1,3,figsize=(10,4))
for i in range(3):
    ax[i].imshow(X.iloc[i].values.reshape(8,8))
    ax[i].set_title(f"This is digit {y[i]}.")
plt.suptitle("First three images.")
plt.show()

# %% [markdown]
# Split data into train and test, let test size be 30% of the dataset and fix random state to 42:

# %%
X_train, X_val, y_train, y_val = ## your code here

# %%
assert y_val.shape[0] == 162
assert y_val.sum() == 169

# %% [markdown]
# Fit a RandomForestClassifier with max_depth=13 and evaluate it's performance:

# %%
clf = RandomForestClassifier(max_depth=13)

# your code here

acc = # your code here
print(acc)

# %%
assert acc > 0.98

# %% [markdown]
# Now we will use Boruta to find redundand pixels. If the package is not installed in your system, uncomment and run the following cell.

# %%
# ! pip install boruta

# %%
from boruta import BorutaPy

feat_selector = BorutaPy(RandomForestClassifier(max_depth=13), 
                         n_estimators='auto', 
                         verbose=0, 
                         max_iter=100,
                         random_state=42)

# your code here: do run the boruta

# %% [markdown]
# Let us print redundant pixels as a mask. Does the result looks similar to mine (or to Among us chracters)?

# %%
mask = np.array(feat_selector.support_).reshape(8,8)
plt.imshow(mask);

# %% [markdown]
# At the end let us redo  classification but only with selected features

# %%
clf = RandomForestClassifier(max_depth=13)

# your code here

acc = # your code here
print(acc)

# %%
assert acc > 0.99

# %% [markdown]
# # Materials & References

# %% [markdown]
# 1. General article about feature engineering and selection (main reference):
# https://github.com/Yorko/mlcourse.ai/blob/master/jupyter_english/topic06_features_regression/topic6_feature_engineering_feature_selection.ipynb
#
# 2. Feature engineering/preprocessing, using scikit-learn API (great code examples, but really brief explanation):
# https://scikit-learn.org/stable/modules/preprocessing
#
# 3. Feature scaling/normalization:
# https://towardsdatascience.com/all-about-feature-scaling-bcc0ad75cb35
#
# 4. Log Transform/power transform:
# https://medium.com/@kyawsawhtoon/log-transformation-purpose-and-interpretation-9444b4b049c9
#
# 6. Missing values preprocessing using scikit-learn API (great code examples, great explanation):
# https://scikit-learn.org/stable/modules/impute.html
#
# 7. Feature selection scikit-learn API (great code examples, great explanation):
# https://scikit-learn.org/stable/modules/feature_selection.html
#
# 8. Melbourne housing dataset source:
# https://www.kaggle.com/anthonypino/melbourne-housing-market
